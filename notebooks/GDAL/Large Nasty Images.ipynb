# %%
import tifffile
from osgeo import gdal

# %%
nasty_img_path = '/Volumes/TOSHIBA EXT/1616.tif'
nasty_img_path = '/Volumes/ExDisk/cor03639_CH2.tif'
#nasty_img_path = '/Users/mader/Dropbox/Informatics/sentinel2-bot-master/new_tiles-32-T-MS-2016-1-3-0-.png'
nasty_img_path = '/Users/mader/Dropbox/4Quant/Projects/TumorSegmentation/10092825/0004_t1_tse_sag_384/20274103.dcm.tif'

# %%
gd_img = gdal.Open(nasty_img_path)

# %%
gd_img.ReadAsArray(256, 256, 384-256, 384-256).swapaxes(0,1)
# Out:
# array([[668, 438, 540, ..., 440, 433, 429],
#        [652, 497, 419, ..., 464, 460, 430],
#        [511, 560, 434, ..., 460, 400, 389],
#        ...,
#        [ 12,  15,   8, ...,  14,  12,   3],
#        [ 17,   9,   7, ...,  11,  11,   3],
#        [  4,   4,   4, ...,   6,   5,   4]], dtype=uint16)

# %%
gd_img.RasterXSize, gd_img.RasterYSize
# Out:
# (22902, 30021)

# %%
gd_img.ReadAsArray(22900,30019, 2, 2)
# Out:
# array([[0, 0],
#        [0, 0]], dtype=uint8)

# %%
gd_img.ReadAsArray(30019, 22900, -2, 2).swapaxes(0,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e42deb0ba026> in <module>()
# ----> 1 gd_img.ReadAsArray(30019, 22900, -2, 2).swapaxes(0,1)
#
# /Users/mader/anaconda/lib/python3.5/site-packages/osgeo/gdal.py in ReadAsArray(self, xoff, yoff, xsize, ysize, buf_obj, buf_xsize, buf_ysize, buf_type, resample_alg, callback, callback_data)
#     843                                                resample_alg = resample_alg,
#     844                                                callback = callback,
# --> 845                                                callback_data = callback_data )
#     846
#     847     def WriteRaster(self, xoff, yoff, xsize, ysize,
#
# ...

# %%
nd_arr = gd_img.ReadAsArray(5000, 5000, 1024, 1024)
# %matplotlib inline
import matplotlib.pyplot as plt
print(nd_arr.shape, nd_arr.dtype, nd_arr.min(), nd_arr.max())
plt.imshow(nd_arr.)
# Out:
# (3, 1024, 1024) uint16 0 65535
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-f93e720840e9> in <module>()
#       3 import matplotlib.pyplot as plt
#       4 print(nd_arr.shape, nd_arr.dtype, nd_arr.min(), nd_arr.max())
# ----> 5 plt.imshow(nd_arr)
#
# /Users/mader/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3020                         filternorm=filternorm, filterrad=filterrad,
#    3021                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3022                         **kwargs)
#    3023     finally:
#    3024         ax.hold(washold)
#
# /Users/mader/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
plt.imshow(nd_arr[1])
